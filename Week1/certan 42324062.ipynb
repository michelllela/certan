# %% [raw]
# TUGAS PRAKTIKUM WEEK 1 SESI 3
# KECERDASAN BUATAN

# %% [raw]
# Nama  : Michelle Sianturi
# NIM   : 42324062
# Prodi : D3 Teknologi Informasi

# %% [raw]
# 1. Buatlah sebuah matriks berukuran 5x5 dengan elemen random. Kemudian dari elemen yang dihasilkan perlihatkan nilai maksimum, nilai minimum dan nilai rata-rata dari suatu
# elemen matriks yang di konstruksi.

# %%
import numpy as np

print("Tugas 1: Matriks 5x5 dengan Bilangan Bulat Random")
matriks = np.random.randint(0, 100, size=(5, 5))  

print("Matriksnya:")
print(matriks)
print("Nilai maksimum:", matriks.max())
print("Nilai minimum :", matriks.min())
print("Rata-rata     :", round(matriks.mean(), 2))
# Out:
# Tugas 1: Matriks 5x5 dengan Bilangan Bulat Random
# Matriksnya:
# [[28 59 38 42 31]
#  [55 25 74 55 82]
#  [95 19 83 40  4]
#  [73  0  2 96  5]
#  [45 54  2 94 24]]
# Nilai maksimum: 96
# Nilai minimum : 0
# Rata-rata     : 45.0

# %% [raw]
# 2. Buatlah grafik 2 dimensi dari persamaan berikut

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-1.5, 1.5, 500)
y = np.linspace(-1.5, 1.5, 500)
X, Y = np.meshgrid(x, y)

F = (X**6 + 3*X**4*Y**2 - 3*X**4 + 3*X**2*Y**4 - 
     X**2*Y**3 - 6*X**2*Y**2 + 3*X**2 + Y**6 - 3*Y**4 + 3*Y**2)

plt.figure(figsize=(7, 7))
plt.contour(X, Y, F, levels=[1], colors="red", linewidths=2)

plt.axhline(0, color="black", linewidth=1)
plt.axvline(0, color="black", linewidth=1)
plt.title(r"Grafik 2D: $x^6 + 3x^4y^2 - 3x^4 + 3x^2y^4 - x^2y^3 - 6x^2y^2 + 3x^2 + y^6 - 3y^4 + 3y^2 = 1$")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %% [raw]
# 3. Buatlah grafik 3 dimensi dari persamaan berikut.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)

Z = ((5 * Y / 4) - np.abs(X))**2 + X**2

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap="viridis", edgecolor="none")

ax.set_title(r"Grafik 3D: $z = \left(\frac{5y}{4} - |x|\right)^2 + x^2$")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")

plt.show()
